# %% [markdown]
# # Spotiify Data Extraction

# %%
import spotipy
import pandas as pd
import math
from spotipy.oauth2 import SpotifyClientCredentials

import warnings
warnings.filterwarnings("ignore")

pd.options.display.max_rows = 6000
pd.options.display.max_columns = 999

# %%
sp = spotipy.Spotify(
    client_credentials_manager=SpotifyClientCredentials(
        client_id='c3c6cbaa304c4c86b120e8d9603d44a4', 
        client_secret='b8819ea70b3142819602499ee139c24f'), retries=20, status_retries=20)

nirvana_uri = 'spotify:artist:1w5Kfo2jwwIPruYS2UWh56'

# %%
pearl_uri = '1w5Kfo2jwwIPruYS2UWh56'

all_tracks = []

def get_data(results):
    albums = results['items']
    
    while results['next']:
        results = sp.next(results)
        albums.extend(results['items'])
    
    for album in albums:
        if album['name'] not in ['Ten', 'Vs.', 'Vitalogy', 'No Code', 'Yield', 'Binaural', 'Riot Act', 'Pearl Jam', 'Backspacer', 'Lightning Bolt' ,'Gigaton', 'Last Kiss', 'Merkin Ball']:
            continue
            
        result = sp.album_tracks(album['uri'])
        tracks = result['items']
        
        while result['next']:
            result = sp.next(result)
            tracks.extend(result['items'])
            
        for track in tracks:
            # if track['id'] == '6DifPvqyEMk6zj0uDvcOpl': continue
            
            new_track = {}
            new_track['track_name'] = track['name']
            new_track['album_name'] = album['name']
            new_track['album_type'] = album['album_type']
            new_track['release_year'] = album['release_date'][0:4]
            new_track['artists'] = ', '.join([artist['name'] for artist in track['artists']])
            new_track['duration'] = math.floor(track['duration_ms']/1000)

            try:
                audio = sp.audio_features(tracks=track['id'])
                new_track['acousticness'] = audio[0]['acousticness']
                new_track['danceability'] = audio[0]['danceability']
                new_track['energy'] = audio[0]['energy']
                new_track['instrumentalness'] = audio[0]['instrumentalness']
                new_track['key'] = audio[0]['key']
                new_track['liveness'] = audio[0]['liveness']
                new_track['loudness'] = audio[0]['loudness']
                new_track['mode'] = audio[0]['mode']
                new_track['speechiness'] = audio[0]['speechiness']
                new_track['tempo'] = audio[0]['tempo']
                new_track['time_signature'] = audio[0]['time_signature']
                new_track['valence'] = audio[0]['valence']
            except:
                break
            
            all_tracks.append(new_track)

get_data(sp.artist_albums(pearl_uri, album_type='album')) # Studio Albums
get_data(sp.artist_albums(pearl_uri, album_type='single')) # Last Kiss and Merkin Ball

# %%
spot = pd.DataFrame(all_tracks)

# %% [markdown]
# ## Cleaning The Data

# %%
# Cleaning Track Names

spot['track_name'] = spot['track_name'].apply(lambda x: x.split(' - ')[0])
spot.loc[114, 'track_name'] = 'Aye Davanita'
spot.loc[14, 'track_name'] = 'My Father\'s Son'
spot.loc[35, 'track_name'] = 'Better Man'
spot.loc[149, 'track_name'] = 'Long Road'

# %%
# Cleaning Album Types

spot.loc[spot['album_type'] == 'single', 'album_type'] = 'extended play'

# %% [markdown]
# ## Saving The Data

# %%
spot.to_csv('pearl_spotify.csv', index=False)

# %% [markdown]
# # Wikipedia Data Extraction

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import re

# %%
url = 'https://en.m.wikipedia.org/wiki/Category:Pearl_Jam_songs'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
links = [x.a['href'] if not x.span else '' for x in soup.find('div', class_='mw-content-ltr').find_all('li')]
while '' in links: links.remove('')
links = links[3:]

# %%
all_tracks = []
for link in links:
    page_link = 'https://en.wikipedia.org' + link
    song_page = requests.get(page_link, )
    soup = BeautifulSoup(song_page.content, 'html.parser')
    
    table_rows = soup.find('table', class_='infobox').find_all('tr')
    
    title = table_rows[0].text.strip('/"')
    
    track = {}
    track['track_title'] = title
    for row in table_rows:
        if row.th and row.td:
            if row.th.text.lower() == 'released':
                release_date = row.find('td').text
                track['release'] = release_date.split('\xa0(')[0].replace('[1]','')[-5:].strip()
            if row.th.text.lower() == 'songwriter(s)':
                authors  = row.td.text
                track['authors'] = ', '.join(authors.replace('[2]','').split('\n')).lstrip(', ').rstrip(', ')
            if row.th.text.lower() == 'producer(s)':
                producers  = row.td.text
                track['producers'] = ', '.join(producers.replace('[1]','').split('\n')).lstrip(', ').rstrip(', ')
    all_tracks.append(track)

df = pd.DataFrame(all_tracks)

# %%
df = df.replace(np.nan,'')
df.sort_values(by='release', inplace=True)
df.to_csv('pearl_wiki.csv', index=False)
wiki = df

# %% [markdown]
# ## Cleaning The data

# %%
indices = [1, 9, 37]
wiki.loc[indices,'track_title'] = wiki.loc[indices,'track_title'].str.title()
wiki.loc[22,'track_title'] = '1/2 Full'

# %% [markdown]
# ## Saving The Data

# %%
pearl_v1 = spot.merge(wiki, how='left', left_on=['track_name'], right_on=['track_title']).drop(['track_title', 'release'], axis=1)
pearl_v1.to_csv('pearl_v1.csv', index=False)

# %% [markdown]
# # AllMusic Data Extraction

# %%
from requests_html import HTMLSession
from bs4 import BeautifulSoup
import pandas as pd

# %%
session = HTMLSession()
url = 'https://www.allmusic.com/artist/pearl-jam-mn0000037730/discography/all'
response = session.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
def get_page_data(url):
    """
    Input a page URL to get a BeautifulSoup object from that page.
    """
    response = session.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %%
def get_album_page_links(soup):
    """
    Input a BeautifulSoup object to get links to all albums present on that discography page
    """
    links = []
    data = soup.find_all('td', class_ = 'title')
    for album in data:
        if album.find('a'):
            links.append(album.find('a')['href'])
    return links

def get_track_page_links(soup):
    """
    Input a BeautifulSoup object to get links to all tracks present on that album page
    """
    links = []
    data = soup.find_all('div', class_ = 'title')
    for track in data:
        if track.find('a'):
            links.append(track.find('a')['href'])
    return links

album_links = get_album_page_links(soup)

# %%
def calculate_rating(classes):
    """
    A function to parse classes from AllMusic website as a rating on a scale from [0.5-5.0].
    This function will expect a list of css classes as a parameter, and output 
    rating according to present class.
    """
    if 'rating-unrated' in classes: rating = ''
    elif 'rating-allmusic-0' in classes: rating = ''
    elif 'rating-allmusic-1' in classes: rating = 1.0
    elif 'rating-allmusic-2' in classes: rating = 1.5
    elif 'rating-allmusic-3' in classes: rating = 2.0
    elif 'rating-allmusic-4' in classes: rating = 2.5
    elif 'rating-allmusic-5' in classes: rating = 3.0
    elif 'rating-allmusic-6' in classes: rating = 3.5
    elif 'rating-allmusic-7' in classes: rating = 4.0
    elif 'rating-allmusic-8' in classes: rating = 4.5
    elif 'rating-allmusic-9' in classes: rating = 5.0
    return rating

# %%
def get_track_data(url):
    """
    This function expects a track URL as a parameter. It returns information about the track
    as a dictionary"""
    overview_page = get_page_data(url)
    attributes_page = get_page_data(str(url +  '/attributes'))
        
    track_title = overview_page.find('h1').text.strip()
    track_composers = [x.a.text for x in overview_page.find_all('p', class_ = 'song-composer')]
    if attributes_page.find('div', class_ = 'attribute-tab-genres'):
        genres = [x.text[:-4] for x in attributes_page.find('div', class_ = 'attribute-tab-genres').find_all('a')]
    styles = [x.text[:-4] for x in attributes_page.find('div', class_ = 'attribute-tab-styles').find_all('a')] 
    moods = [x.text[:-4] for x in attributes_page.find('div', class_ = 'attribute-tab-moods').find_all('a')] 
    themes = [x.text[:-4] for x in attributes_page.find('div', class_ = 'attribute-tab-themes').find_all('a')] 
        
    return {
        'track_title' : track_title,
        'track_composers' : track_composers,
        'track_genres':genres, 
        'track_styles':styles, 
        'track_moods':moods, 
        'track_themes':themes
    }

# %%
def get_data(url):
    """
    This function expects an album page URL. It will scrape all data about the album and all tracks from that album.
    It will return a list of all tracks from that album with its corresponding information as a dictionary"""

    # ALBUM data
    album_page = get_page_data(url)
    album_title = album_page.find('h1', class_ = 'album-title').text.strip()
    if album_title not in ['Ten', 'Vs.', 'Vitalogy', 'No Code', 'Yield', 'Binaural', 'Riot Act', 'Pearl Jam', 'Backspacer', 'Lightning Bolt' ,'Gigaton', 'Last Kiss', 'Merkinball']:
        return []
    album_release_date = [album_page.find('div', class_ = 'release-date').span.text if album_page.find('div', class_ = 'release-date') else '']
    album_duration = [album_page.find('div', class_ = 'duration').text.strip() if album_page.find('div', class_ = 'duration') else None ]
    album_genre = [album_page.find('div', class_ = 'genre').div.a.text if album_page.find('div', class_ = 'genre') else '']
    album_styles = [[a.text for a in album_page.find('div', class_ = 'styles').find_all('a')] if album_page.find('div', class_ = 'styles') else '']
    album_recording_date = [album_page.find('div', class_ = 'recording-date').div.text if album_page.find('div', class_ = 'recording-date') else '']
    album_recording_location = [album_page.find('div', class_ = 'recording-location').li.text.strip() if album_page.find('div', class_ = 'recording-location') else '']
    album_moods = [x.text.strip() for x in album_page.find_all('span', class_ = 'mood')]
    album_themes = [x.text.strip() for x in album_page.find_all('span', class_ = 'theme')]
    album_rating = calculate_rating(album_page.find('div', class_ = 'allmusic-rating').get('class'))

    # TRACK data
    all_tracks_data = []
    track_links = get_track_page_links(album_page)
    if len(track_links) > 0:
        for track_link in track_links:
            all_tracks_data.append(get_track_data(track_link))

    # FINAL data
    final_data = []
    
    for track in all_tracks_data:
        final_data.append({
            'track_title' : track['track_title'],
            'track_composers' : track['track_composers'],
            'track_genres': track['track_genres'], 
            'track_styles': track['track_styles'], 
            'track_moods': track['track_moods'], 
            'track_themes': track['track_themes'],
            'album_title': album_title,
            'album_release_date': album_release_date,
            'album_duration' : album_duration,
            'album_genres' : album_genre,
            'album_styles' : album_styles,
            'album_recording_date' : album_recording_date,
            'album_recording_location' : album_recording_location,
            'album_moods' : album_moods,
            'album_themes' : album_themes,
            'album_rating' : album_rating
        })
    return final_data

# %% [markdown]
# ### Fetching all data from AllMusic

# %%
all_tracks  = []
for i in range(len(album_links)):
    all_tracks.extend(get_data(album_links[i]))

# %% [markdown]
# ### Cleaning The Data

# %%
df = pd.DataFrame(all_tracks)
allmusic = df

# %%
allmusic.drop('album_genres', axis=1, inplace=True)

# %%
print(f'Columns:\t{allmusic.shape[1]}\nRows:\t\t{allmusic.shape[0]}')
# Out:
# Columns:	15
# Rows:		144

# %%
allmusic['track_composers'] = allmusic['track_composers'].apply(lambda x: ', '.join(x))
allmusic['track_genres'] = allmusic['track_genres'].apply(lambda x: ', '.join(x))
allmusic['track_styles'] = allmusic['track_styles'].apply(lambda x: ', '.join(x))
allmusic['track_moods'] = allmusic['track_moods'].apply(lambda x: ', '.join(x))
allmusic['track_themes'] = allmusic['track_themes'].apply(lambda x: ', '.join(x))
allmusic['album_duration'] = allmusic['album_duration'].apply(lambda x: str(x[0])[9:])
allmusic['album_styles'] = allmusic['album_styles'].apply(lambda x: ''.join(x[0]))
allmusic['album_recording_date'] = allmusic['album_recording_date'].apply(lambda x: ', '.join(x))
allmusic['album_release_date'] = allmusic['album_release_date'].apply(lambda x: str(x)[-6:-2])
allmusic['album_recording_location'] = allmusic['album_recording_location'].apply(lambda x: ', '.join(x))
allmusic['album_moods'] = allmusic['album_moods'].apply(lambda x: ', '.join(x))
allmusic['album_themes'] = allmusic['album_themes'].apply(lambda x: ', '.join(x))

# %%
# Cleaning the missing data format
allmusic.loc[df['track_genres'] == 'Would you like to contrib', 'track_genres'] = ''
allmusic.loc[df['track_styles'] == 'Would you like to contrib', 'track_styles'] = ''
allmusic.loc[df['track_moods'] == 'Would you like to contrib', 'track_moods'] = ''
allmusic.loc[df['track_themes'] == 'Would you like to contrib', 'track_themes'] = ''

# %%
allmusic
# Out:
#                                           track_title  \
# 0                                                Once
# 1                                           Even Flow
# 2                                               Alive
# 3                                              Why Go
# 4                                               Black
# 5                                              Jeremy
# 6                                              Oceans
# 7                                               Porch
# 8                                              Garden
# 9                                                Deep
# 10                                            Release
# 11                                                 Go
# 12                                             Animal
# 13                                           Daughter
# 14                                        Glorified G
# 15                                          Dissident
# 16                                             W.M.A.
# 17                                              Blood
# 18                                     Rearviewmirror
# 19                                               Rats
# 20   Elderly Woman Behind the Counter in a Small Town
# 21                                              Leash
# 22                                       Indifference
# 23                                          Last Exit
# 24                              Spin the Black Circle
# 25                                        Not For You
# 26                                      Tremor Christ
# 27                                         Nothingman
# 28                                           Whipping
# 29                                            Pry, To
# 30                                           Corduroy
# 31                                               Bugs
# 32                                        Satan's Bed
# 33                                         Better Man
# 34                                       Aye Davanita
# 35                                        Immortality
# 36                   Hey Foxymophandlemama, That's Me
# 37                                         I Got Shit
# 38                                          Long Road
# 39                                          Sometimes
# 40                                         Hail, Hail
# 41                                        Who You Are
# 42                                         In My Tree
# 43                                              Smile
# 44                                        Off He Goes
# 45                                              Habit
# 46                                       Red Mosquito
# 47                                              Lukin
# 48                                      Present Tense
# 49                                            Mankind
# 50                                           I'm Open
# 51                                    Around the Bend
# 52                                        Brain of J.
# 53                                          Faithfull
# 54                                             No Way
# 55                                       Given to Fly
# 56                                           Wishlist
# 57                                             Pilate
# 58                                   Do the Evolution
# 59                                   [Untitled Track]
# 60                                                MFC
# 61                                          Low Light
# 62                                          In Hiding
# 63                                   Push Me, Pull Me
# 64                               All Those Yesterdays
# 65                                          Last Kiss
# 66               Soldier of Love (Lay Down Your Arms)
# 67                                        Breakerfall
# 68                                         God's Dice
# 69                                         Evacuation
# 70                                        Light Years
# 71                                Nothing as It Seems
# 72                                           Thin Air
# 73                                     Insignificance
# 74                                        Of the Girl
# 75                                          Grievance
# 76                                              Rival
# 77                                    Sleight of Hand
# 78                                        Soon Forget
# 79                                       Parting Ways
# 80                                         Can't Keep
# 81                                           Save You
# 82                                  Love Boat Captain
# 83                                         Cropduster
# 84                                              Ghost
# 85                                          I Am Mine
# 86                                    Thumbing My Way
# 87                                            You Are
# 88                                          Get Right
# 89                                      Green Disease
# 90                                          Help Help
# 91                                        Bushleaguer
# 92                                           1/2 Full
# 93                                                Arc
# 94                                        All Or None
# 95                                        Life Wasted
# 96                                 World Wide Suicide
# 97                                           Comatose
# 98                                       Severed Hand
# 99                                 Marker in the Sand
# 100                                        Parachutes
# 101                                      Unemployable
# 102                                          Big Wave
# 103                                              Gone
# 104                                    Wasted Reprise
# 105                                      Army Reserve
# 106                                         Come Back
# 107                                        Inside Job
# 108                               Gonna See My Friend
# 109                                          Got Some
# 110                                         The Fixer
# 111                                     Johnny Guitar
# 112                                      Just Breathe
# 113                                 Amongst the Waves
# 114                                   Unthought Known
# 115                                        Supersonic
# 116                                    Speed of Sound
# 117                                   Force of Nature
# 118                                           The End
# 119                                    [CD-ROM Track]
# 120                                           Getaway
# 121                                 Mind Your Manners
# 122                                   My Father's Son
# 123                                            Sirens
# 124                                    Lightning Bolt
# 125                                        Infallible
# 126                                          Pendulum
# 127                                   Swallowed Whole
# 128                              Let the Records Play
# 129                                Sleeping By Myself
# 130                                       Yellow Moon
# 131                                       Future Days
# 132                                     Who Ever Said
# 133                               Superblood Wolfmoon
# 134                         Dance of the Clairvoyants
# 135                                      Quick Escape
# 136                                           Alright
# 137                                     Seven O'Clock
# 138                                 Never Destination
# 139                                 Take the Long Way
# 140                                         Buckle Up
# 141                                   Comes Then Goes
# 142                                        Retrograde
# 143                                       River Cross
#
#                                        track_composers  \
# 0                          Stone Gossard, Eddie Vedder
# 1                          Stone Gossard, Eddie Vedder
# 2                          Stone Gossard, Eddie Vedder
# 3                             Jeff Ament, Eddie Vedder
# 4                          Stone Gossard, Eddie Vedder
# 5                             Jeff Ament, Eddie Vedder
# 6              Jeff Ament, Stone Gossard, Eddie Vedder
# 7                                         Eddie Vedder
# 8              Jeff Ament, Stone Gossard, Eddie Vedder
# 9              Jeff Ament, Stone Gossard, Eddie Vedder
# 10   Jeff Ament, Stone Gossard, Dave Krusen, Mike M...
# 11   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 12   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 13   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 14   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 15   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 16   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 17   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 18   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 19   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 20   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 21   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 22   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 23   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 24   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 25   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 26   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 27                            Jeff Ament, Eddie Vedder
# 28   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 29   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 30   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 31   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 32          Stone Gossard, Mike McCready, Eddie Vedder
# 33                                        Eddie Vedder
# 34   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 35   Dave Abbruzzese, Jeff Ament, Stone Gossard, Mi...
# 36   Jeff Ament, Stone Gossard, Jack Irons, Mike Mc...
# 37   Jack Irons, Brendan O'Brien, Eddie Vedder, Nei...
# 38    Jeff Ament, Jack Irons, Eddie Vedder, Neil Young
# 39                                        Eddie Vedder
# 40   Carrie Akre, Jeff Ament, Stone Gossard, Mike M...
# 41             Stone Gossard, Jack Irons, Eddie Vedder
# 42             Stone Gossard, Jack Irons, Eddie Vedder
# 43                            Jeff Ament, Eddie Vedder
# 44                                        Eddie Vedder
# 45                                        Eddie Vedder
# 46                             Pearl Jam, Eddie Vedder
# 47                                        Eddie Vedder
# 48                         Mike McCready, Eddie Vedder
# 49                                       Stone Gossard
# 50                            Jack Irons, Eddie Vedder
# 51                                        Eddie Vedder
# 52                         Mike McCready, Eddie Vedder
# 53                         Mike McCready, Eddie Vedder
# 54                                       Stone Gossard
# 55                                       Mike McCready
# 56                                        Eddie Vedder
# 57                                          Jeff Ament
# 58                         Stone Gossard, Eddie Vedder
# 59                                        Eddie Vedder
# 60                                        Eddie Vedder
# 61                                          Jeff Ament
# 62                         Stone Gossard, Eddie Vedder
# 63                            Jeff Ament, Eddie Vedder
# 64                                       Stone Gossard
# 65                                       Wayne Cochran
# 66                               Buzz Cason, Tony Moon
# 67                                        Eddie Vedder
# 68                                          Jeff Ament
# 69                          Matt Cameron, Eddie Vedder
# 70          Stone Gossard, Mike McCready, Eddie Vedder
# 71                                          Jeff Ament
# 72                                       Stone Gossard
# 73                                        Eddie Vedder
# 74                                       Stone Gossard
# 75                                        Eddie Vedder
# 76                                       Stone Gossard
# 77                            Jeff Ament, Eddie Vedder
# 78                                        Eddie Vedder
# 79                                        Eddie Vedder
# 80                                        Eddie Vedder
# 81   Jeff Ament, Matt Cameron, Stone Gossard, Mike ...
# 82                           Boom Gaspar, Eddie Vedder
# 83                          Matt Cameron, Eddie Vedder
# 84                            Jeff Ament, Eddie Vedder
# 85                                        Eddie Vedder
# 86                                        Eddie Vedder
# 87                          Matt Cameron, Eddie Vedder
# 88                                        Matt Cameron
# 89                                        Eddie Vedder
# 90                                          Jeff Ament
# 91                         Stone Gossard, Eddie Vedder
# 92                            Jeff Ament, Eddie Vedder
# 93                                        Eddie Vedder
# 94                         Stone Gossard, Eddie Vedder
# 95                         Stone Gossard, Eddie Vedder
# 96                                        Eddie Vedder
# 97          Stone Gossard, Mike McCready, Eddie Vedder
# 98                                        Eddie Vedder
# 99                         Mike McCready, Eddie Vedder
# 100                        Stone Gossard, Eddie Vedder
# 101          Matt Cameron, Mike McCready, Eddie Vedder
# 102                           Jeff Ament, Eddie Vedder
# 103                                       Eddie Vedder
# 104                        Stone Gossard, Eddie Vedder
# 105            Jeff Ament, Damien Echols, Eddie Vedder
# 106                        Mike McCready, Eddie Vedder
# 22   Angst-Ridden, Autumnal, Bittersweet, Earnest, ...
# 23   Aggressive, Angst-Ridden, Brooding, Cathartic,...
# 24   Aggressive, Angst-Ridden, Autumnal, Cathartic,...
# 25   Aggressive, Angst-Ridden, Brooding, Cathartic,...
# 26   Angst-Ridden, Cathartic, Dramatic, Freewheelin...
# 27   Autumnal, Bittersweet, Gentle, Intimate, Melan...
# 28   Aggressive, Angst-Ridden, Autumnal, Cathartic,...
# 29
# 30   Aggressive, Brooding, Fiery, Intense, Raucous,...
# 31
# 32                          Aggressive, Brash, Demonic
# 33   Exuberant, Yearning, Dramatic, Earnest, Passio...
# 34
# 35   Angst-Ridden, Bittersweet, Intense, Melancholy...
# 36
# 37                                  Brooding, Yearning
# 38           Brooding, Laid-Back/Mellow, Sad, Yearning
# 39   Earnest, Freewheeling, Poignant, Quirky, Refle...
# 40   Angst-Ridden, Brooding, Cathartic, Earnest, Ra...
# 41                        Yearning, Lively, Optimistic
# 42   Aggressive, Angst-Ridden, Brooding, Cathartic,...
# 43      Aggressive, Angry, Brooding, Rousing, Yearning
# 44   Autumnal, Earnest, Angst-Ridden, Bittersweet, ...
# 45                                          Aggressive
# 46                                             Rousing
# 47   Angst-Ridden, Brooding, Bittersweet, Cathartic...
# 48                                            Yearning
# 49                                   Brooding, Rousing
# 50                                    Brooding, Quirky
# 51               Calm/Peaceful, Nostalgic, Sentimental
# 52                                          Aggressive
# 53                                            Yearning
# 54                                            Brooding
# 55   Angst-Ridden, Brooding, Amiable/Good-Natured, ...
# 56   Angst-Ridden, Brooding, Bittersweet, Earnest, ...
# 57                                            Yearning
# 58   Aggressive, Angst-Ridden, Brooding, Confrontat...
# 59                                   Energetic, Quirky
# 60   Angst-Ridden, Brooding, Confrontational, Earne...
# 61   Autumnal, Earnest, Aggressive, Angst-Ridden, B...
# 62   Angst-Ridden, Cathartic, Earnest, Urgent, Visc...
# 63                                            Yearning
# 64                       Laid-Back/Mellow, Sentimental
# 65   Bittersweet, Dramatic, Melancholy, Poignant, S...
# 66   Amiable/Good-Natured, Earnest, Exuberant, Swee...
# 67   Cathartic, Fiery, Intense, Outraged, Uncomprom...
# 68                                Aggressive, Yearning
# 69                              Aggressive, Boisterous
# 70   Angst-Ridden, Brooding, Bittersweet, Earnest, ...
# 71   Angst-Ridden, Brooding, Bittersweet, Earnest, ...
# 72                          Laid-Back/Mellow, Yearning
# 73   Cathartic, Fiery, Intense, Outraged, Uncomprom...
# 74                                    Laid-Back/Mellow
# 75   Cathartic, Fiery, Intense, Outraged, Uncomprom...
# 76                                            Brooding
# 77                                            Brooding
# 78   Earnest, Intense, Quirky, Tense/Anxious, Intim...
# 79                                            Brooding
# 80   Angry, Brooding, Yearning, Nostalgic, Sentimental
# 81   Angst-Ridden, Brooding, Cathartic, Earnest, Fi...
# 82   Autumnal, Brooding, Earnest, Aggressive, Angst...
# 83            Brooding, Optimistic, Romantic, Yearning
# 84                                  Dramatic, Yearning
# 85   Autumnal, Earnest, Aggressive, Angst-Ridden, B...
# 10                   Empowerment, Revolution, Solitude           5.0
# 11                Heartache, Introspection, Loss/Grief           4.0
# 12                Heartache, Introspection, Loss/Grief           4.0
# 13                Heartache, Introspection, Loss/Grief           4.0
# 14                Heartache, Introspection, Loss/Grief           4.0
# 15                Heartache, Introspection, Loss/Grief           4.0
# 16                Heartache, Introspection, Loss/Grief           4.0
# 17                Heartache, Introspection, Loss/Grief           4.0
# 18                Heartache, Introspection, Loss/Grief           4.0
# 19                Heartache, Introspection, Loss/Grief           4.0
# 20                Heartache, Introspection, Loss/Grief           4.0
# 21                Heartache, Introspection, Loss/Grief           4.0
# 22                Heartache, Introspection, Loss/Grief           4.0
# 23                Heartache, Introspection, Loss/Grief           4.5
# 24                Heartache, Introspection, Loss/Grief           4.5
# 25                Heartache, Introspection, Loss/Grief           4.5
# 26                Heartache, Introspection, Loss/Grief           4.5
# 27                Heartache, Introspection, Loss/Grief           4.5
# 28                Heartache, Introspection, Loss/Grief           4.5
# 29                Heartache, Introspection, Loss/Grief           4.5
# 30                Heartache, Introspection, Loss/Grief           4.5
# 31                Heartache, Introspection, Loss/Grief           4.5
# 32                Heartache, Introspection, Loss/Grief           4.5
# 33                Heartache, Introspection, Loss/Grief           4.5
# 34                Heartache, Introspection, Loss/Grief           4.5
# 35                Heartache, Introspection, Loss/Grief           4.5
# 36                Heartache, Introspection, Loss/Grief           4.5
# 37                                                               2.5
# 38                                                               2.5
# 39   Cool & Cocky, Introspection, Passion, Reflecti...           3.5
# 40   Cool & Cocky, Introspection, Passion, Reflecti...           3.5
# 41   Cool & Cocky, Introspection, Passion, Reflecti...           3.5
# 42   Cool & Cocky, Introspection, Passion, Reflecti...           3.5
# 43   Cool & Cocky, Introspection, Passion, Reflecti...           3.5
# 44   Cool & Cocky, Introspection, Passion, Reflecti...           3.5
# 45   Cool & Cocky, Introspection, Passion, Reflecti...           3.5
# 46   Cool & Cocky, Introspection, Passion, Reflecti...           3.5
# 47   Cool & Cocky, Introspection, Passion, Reflecti...           3.5
# 48   Cool & Cocky, Introspection, Passion, Reflecti...           3.5
# 49   Cool & Cocky, Introspection, Passion, Reflecti...           3.5
# 50   Cool & Cocky, Introspection, Passion, Reflecti...           3.5
# 51   Cool & Cocky, Introspection, Passion, Reflecti...           3.5
# 52   Cool & Cocky, Introspection, Passion, Reflecti...           2.5
# 53   Cool & Cocky, Introspection, Passion, Reflecti...           2.5
# 54   Cool & Cocky, Introspection, Passion, Reflecti...           2.5
# 55   Cool & Cocky, Introspection, Passion, Reflecti...           2.5
# 56   Cool & Cocky, Introspection, Passion, Reflecti...           2.5
# 57   Cool & Cocky, Introspection, Passion, Reflecti...           2.5
# 58   Cool & Cocky, Introspection, Passion, Reflecti...           2.5
# 59   Cool & Cocky, Introspection, Passion, Reflecti...           2.5
# 60   Cool & Cocky, Introspection, Passion, Reflecti...           2.5
# 61   Cool & Cocky, Introspection, Passion, Reflecti...           2.5
# 62   Cool & Cocky, Introspection, Passion, Reflecti...           2.5
# 63   Cool & Cocky, Introspection, Passion, Reflecti...           2.5
# 64   Cool & Cocky, Introspection, Passion, Reflecti...           2.5
# 65                                                               2.0
# 66                                                               2.0
# 67   Cool & Cocky, Introspection, Passion, Reflecti...           4.0
# 68   Cool & Cocky, Introspection, Passion, Reflecti...           4.0
# 69   Cool & Cocky, Introspection, Passion, Reflecti...           4.0
# 70   Cool & Cocky, Introspection, Passion, Reflecti...           4.0
# 71   Cool & Cocky, Introspection, Passion, Reflecti...           4.0
# 72   Cool & Cocky, Introspection, Passion, Reflecti...           4.0
# 73   Cool & Cocky, Introspection, Passion, Reflecti...           4.0
# 74   Cool & Cocky, Introspection, Passion, Reflecti...           4.0
# 75   Cool & Cocky, Introspection, Passion, Reflecti...           4.0
# 76   Cool & Cocky, Introspection, Passion, Reflecti...           4.0
# 77   Cool & Cocky, Introspection, Passion, Reflecti...           4.0
# 78   Cool & Cocky, Introspection, Passion, Reflecti...           4.0
# 79   Cool & Cocky, Introspection, Passion, Reflecti...           4.0
# 80                                             Freedom           4.0
# 81                                             Freedom           4.0
# 82                                             Freedom           4.0
# 83                                             Freedom           4.0
# 84                                             Freedom           4.0
# 85                                             Freedom           4.0
# 86                                             Freedom           4.0
# 87                                             Freedom           4.0
# 88                                             Freedom           4.0
# 89                                             Freedom           4.0
# 90                                             Freedom           4.0
# 91                                             Freedom           4.0
# 92                                             Freedom           4.0
# 93                                             Freedom           4.0
# 94                                             Freedom           4.0
# 95   Hanging Out, Introspection, Reflection, Revolu...           4.5
# 96   Hanging Out, Introspection, Reflection, Revolu...           4.5
# 97   Hanging Out, Introspection, Reflection, Revolu...           4.5
# 98   Hanging Out, Introspection, Reflection, Revolu...           4.5
# 99   Hanging Out, Introspection, Reflection, Revolu...           4.5
# 100  Hanging Out, Introspection, Reflection, Revolu...           4.5
# 101  Hanging Out, Introspection, Reflection, Revolu...           4.5
# 102  Hanging Out, Introspection, Reflection, Revolu...           4.5
# 103  Hanging Out, Introspection, Reflection, Revolu...           4.5
# 104  Hanging Out, Introspection, Reflection, Revolu...           4.5
# 105  Hanging Out, Introspection, Reflection, Revolu...           4.5
# 106  Hanging Out, Introspection, Reflection, Revolu...           4.5
# 107  Hanging Out, Introspection, Reflection, Revolu...           4.5
# 108                            Empowerment, Revolution           4.5
# 109                            Empowerment, Revolution           4.5
# 110                            Empowerment, Revolution           4.5
# 111                            Empowerment, Revolution           4.5
# 112                            Empowerment, Revolution           4.5
# 113                            Empowerment, Revolution           4.5
# 114                            Empowerment, Revolution           4.5
# 115                            Empowerment, Revolution           4.5
# 116                            Empowerment, Revolution           4.5
# 117                            Empowerment, Revolution           4.5
# 118                            Empowerment, Revolution           4.5
# 119                            Empowerment, Revolution           4.5
# 120  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 121  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 122  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 123  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 124  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 125  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 126  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 127  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 128  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 129  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 130  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 131  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 132  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 133  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 134  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 135  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 136  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 137  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 138  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 139  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 140  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 141  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 142  Empowerment, Revolution, Guys Night Out, Night...           4.0
# 143  Empowerment, Revolution, Guys Night Out, Night...           4.0

# %%
# Cleaning the track names

indices = [71, 98, 113, 116, 117, 128, 134, 139]
allmusic.loc[indices, 'track_title'] = allmusic.loc[indices, 'track_title'].str.title()

allmusic.loc[91, 'track_title'] = 'Bu$hleaguer'
allmusic.loc[93, 'track_title'] = 'All or None'
allmusic.loc[68, 'track_title'] = 'Gods\' Dice'
allmusic.loc[66, 'track_title'] = 'Soldier of Love'
allmusic.loc[53, 'track_title'] = 'Faithful'
allmusic.loc[59, 'track_title'] = 'Red Bar'
allmusic.loc[25, 'track_title'] = 'Not for You'
allmusic.loc[36, 'track_title'] = 'Stupidmop'
allmusic.loc[122, 'track_title'] = 'My Father\'s Son'
allmusic.loc[37, 'track_title'] = 'I Got Id'

# Cleaning album names

allmusic.loc[allmusic['album_title'] == 'Merkinball', 'album_title'] = 'Merkin Ball'

# %% [markdown]
# ## Saving The Data

# %%
allmusic.to_csv('pearl_allmusic.csv', index=False)

# %%
pearl_v2 = pearl_v1.merge(allmusic, how='left', left_on=['track_name', 'album_name'], right_on=['track_title', 'album_title']).drop(['track_title', 'album_title'], axis=1)
pearl_v2.to_csv('pearl_v2.csv', index=False)

# %% [markdown]
# # Billboard Data Extraction

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import pandas as pd

# %%
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

driver.get("https://www.billboard.com/artist/pearl-jam/")

# %%
def extract_data(chart_name = ""):
    data = []
    
    table = driver.find_element(By.CLASS_NAME, 'artist-chart-history-items')
    rows = table.find_elements(By.XPATH, '*')
    
    for row in rows:
        track = {}
        track_name = row.find_element(By.ID, 'title-of-a-story')
        debut_date = row.find_element(By.CLASS_NAME, 'artist-chart-row-debut-date')
        peak_pos = row.find_element(By.CLASS_NAME, 'artist-chart-row-peak-pos')
        peak_date = row.find_element(By.CLASS_NAME, 'artist-chart-row-peak-date')
        weaks_on_chart = row.find_element(By.CLASS_NAME, 'artist-chart-row-week-on-chart')

        track['chart'] = chart_name
        track['track_name'] = track_name.text
        track['debut_date']  = debut_date.text
        track['peak_pos'] = peak_pos.text
        track['peak_date'] = peak_date.text
        track['weaks_on_chart'] = weaks_on_chart.text
        data.append(track)
    
    return data

# %%
import time

driver.refresh()

filter = driver.find_element(By.XPATH, '//*[@id="artist-chart-selector"]')
current_li = 1

all_data = []

while(True):
    if current_li == 55:
        break
        
    filter.click()

    time.sleep(1)
    
    li_path = f'//*[@id="main-wrapper"]/main/div[2]/div[2]/div/div[2]/div[1]/nav/ul/li[{current_li}]/a'
    new_li = driver.find_element(By.XPATH, li_path)
    new_li.click()

    time.sleep(1)

    print(f"Chart: {new_li.get_attribute('text').strip()}", end='\r')
    
    all_data.extend(extract_data(chart_name=new_li.get_attribute('text').strip()))
    
    current_li += 1
driver.refresh()
# Out:
# Chart: Rock & Alternative Producersrtm Rock Songsndex

# %%
import pandas as pd

bill = pd.DataFrame(all_data)

# %%
# Taking into consideration only song charts

bill['chart'].value_counts()
useful_charts = [
    'Mainstream Rock Airplay',
    'Alternative Airplay',
    'Radio Songs', 
    'LyricFind U.S.',
    'Billboard Hot 100',
    'Rock Digital Song Sales',
    'Hot Alternative Songs',
    'LyricFind Global',
    'Alternative Digital Song Sales',
    'Billboard Global 200',
    'Canadian Digital Song Sales',
    'Hot Rock Songs',
    'Hot Rock & Alternative Songs',
    'Digital Song Sales',
    'Rock Streaming Songs',
    'Alternative Streaming Songs'
    ]
indices = bill.loc[bill['chart'].isin(useful_charts),].index

bill = bill.loc[indices,]
bill.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Cleaning Billboard Data

# %%
# Indices of 'I Got Id/Long Road'
indices = bill.loc[bill['track_name'] == 'I Got Id/Long Road', ['chart', 'debut_date', 'peak_pos', 'peak_date', 'weaks_on_chart']].index
for i in indices:
    new_row = pd.DataFrame(bill.loc[i,]).transpose()
    track_names = new_row['track_name'].str.split('/')
    bill.loc[i, 'track_name'] = list(track_names)[0][0]
    new_row['track_name'] = list(track_names)[0][1]
    bill = pd.concat([bill, new_row])

# %%
bill.reset_index(inplace=True)

# %%
# Cleaning Song Names

# bill.loc[bill['track_name'].str.lower().str.contains('given to fly'), 'track_name'] = 'Given to Fly'
bill.loc[[33, 37], 'track_name'] = 'Last Kiss'

# %% [markdown]
# ## Saving Billboard Data

# %%
bill.to_csv('pearl_billboard.csv', index=False)

# %% [markdown]
# ## Creating Billboard Charts Columns

# %%
bill['chart'] = bill['chart'].apply(lambda x: x.replace('\xa0',' '))
pearl = pd.read_csv('pearl_v2.csv')
pearl.drop_duplicates(subset=['track_name', 'album_name', 'release_year'], inplace=True)

# %%
for i in range(bill.shape[0]):

    if pearl.loc[pearl['track_name'].str.title() == bill.loc[i,'track_name'],].index.size == 1:
        # If song has only one occurence in pearl_v2 then input Billboard data there
        chart = bill.loc[i,'chart'].lower().replace(' ','_')
        track = bill.loc[i,'track_name']
        index = pearl.loc[pearl['track_name'].str.title() == bill.loc[i,'track_name'],].index[0]

        if chart + '_debut_date' not in pearl.columns: pearl[chart + '_debut_date'] = ''
        pearl[chart + '_debut_date'][index] = bill.loc[i,'debut_date']

        if chart + '_peak_pos' not in pearl.columns: pearl[chart + '_peak_pos'] = ''
        pearl[chart + '_peak_pos'][index] = bill.loc[i,'peak_pos']

        if chart + '_peak_date' not in pearl.columns: pearl[chart + '_peak_date'] = ''
        pearl[chart + '_peak_date'][index] = bill.loc[i,'peak_date']

        if chart + '_weaks_on_chart' not in pearl.columns: pearl[chart + '_weaks_on_chart'] = ''
        pearl[chart + '_weaks_on_chart'][index] = bill.loc[i,'weaks_on_chart']

# %%
pearl.to_csv('pearl_v3.csv', index=False)
