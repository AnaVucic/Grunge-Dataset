# %% [markdown]
# # Nirvana Dataset

# %%
import spotipy
import pandas as pd
import math
from spotipy.oauth2 import SpotifyClientCredentials

pd.options.display.max_rows = 999

# %%
spotify = spotipy.Spotify(
    client_credentials_manager=SpotifyClientCredentials(
        client_id='c3c6cbaa304c4c86b120e8d9603d44a4', 
        client_secret='b8819ea70b3142819602499ee139c24f'))

nirvana_uri = 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'

# %% [markdown]
# #### Collecting data from albums

# %%
results = spotify.artist_albums(nirvana_uri, album_type='album')

albums = results['items']

tracks_with_albums = {}

album_names = []
track_names = []
duration = []
release_date = []
artists = []

acousticness = []
danceability = []
energy = []
instrumentalness = []
key = []
liveness = []
loudness = []
mode = []
speechiness = []
tempo = []
time_signature = []
valence = []

for album in albums:
    tracks = spotify.album_tracks(album['id'])['items']
    audio = spotify.audio_features(tracks=[track['id'] for track in tracks])
    i=0
    for track in tracks:
        track_names.append(track['name'])
        album_names.append(album['name'])
        duration.append(math.floor(track['duration_ms']/1000))
        release_date.append(album['release_date'])
        artists.append(''.join([artist['name'] for artist in track['artists']]))
        
        acousticness.append(audio[i]['acousticness'])
        danceability.append(audio[i]['danceability'])
        energy.append(audio[i]['energy'])
        instrumentalness.append(audio[i]['instrumentalness'])
        key.append(audio[i]['key'])
        liveness.append(audio[i]['liveness'])
        loudness.append(audio[i]['loudness'])
        mode.append(audio[i]['mode'])
        speechiness.append(audio[i]['speechiness'])
        tempo.append(audio[i]['tempo'])
        time_signature.append(audio[i]['time_signature'])
        valence.append(audio[i]['valence'])
        i+=1

        
tracks_with_albums['track_name'] = track_names

tracks_with_albums['album_name'] = album_names

tracks_with_albums['duration'] = duration

tracks_with_albums['release_date'] = release_date

tracks_with_albums['artists'] = artists


tracks_with_albums['acousticness'] = acousticness
tracks_with_albums['danceability'] = danceability
tracks_with_albums['energy'] = energy
tracks_with_albums['instrumentalness'] = instrumentalness
tracks_with_albums['key'] = key
tracks_with_albums['liveness'] = liveness
tracks_with_albums['loudness'] = loudness
tracks_with_albums['mode'] = mode
tracks_with_albums['speechiness'] = speechiness
tracks_with_albums['tempo'] = tempo
tracks_with_albums['time_signature'] = time_signature
tracks_with_albums['valence'] = valence

# %%
for album in albums:
    tracks = spotify.album_tracks(album['id'])['items']
    
    for track in tracks:
        [artist['name'] for artist in track['artists']]

# %% [markdown]
# #### Collecting data from collections

# %%
results = spotify.artist_albums(nirvana_uri, album_type='compilation')

compilations = results['items']

tracks_with_compilations = {}

compilation_names = []
track_names = []
duration = []
release_date = []
artists = []

acousticness = []
danceability = []
energy = []
instrumentalness = []
key = []
liveness = []
loudness = []
mode = []
speechiness = []
tempo = []
time_signature = []
valence = []

for compilation in compilations:
    tracks = spotify.album_tracks(album['id'])['items']
    audio = spotify.audio_features(tracks=[track['id'] for track in tracks])
    i=0
    for track in tracks:
        track_names.append(track['name'])
        compilation_names.append(compilation['name'])
        duration.append(math.floor(track['duration_ms']/1000))
        release_date.append(album['release_date'])
        artists.append(''.join([artist['name'] for artist in track['artists']]))
        
        acousticness.append(audio[i]['acousticness'])
        danceability.append(audio[i]['danceability'])
        energy.append(audio[i]['energy'])
        instrumentalness.append(audio[i]['instrumentalness'])
        key.append(audio[i]['key'])
        liveness.append(audio[i]['liveness'])
        loudness.append(audio[i]['loudness'])
        mode.append(audio[i]['mode'])
        speechiness.append(audio[i]['speechiness'])
        tempo.append(audio[i]['tempo'])
        time_signature.append(audio[i]['time_signature'])
        valence.append(audio[i]['valence'])
        i+=1

        
tracks_with_compilations['track_name'] = track_names

tracks_with_compilations['compilation_name'] = compilation_names

tracks_with_compilations['duration'] = duration

tracks_with_compilations['release_date'] = release_date

tracks_with_compilations['artists'] = artists

tracks_with_compilations['acousticness'] = acousticness
tracks_with_compilations['danceability'] = danceability
tracks_with_compilations['energy'] = energy
tracks_with_compilations['instrumentalness'] = instrumentalness
tracks_with_compilations['key'] = key
tracks_with_compilations['liveness'] = liveness
tracks_with_compilations['loudness'] = loudness
tracks_with_compilations['mode'] = mode
tracks_with_compilations['speechiness'] = speechiness
tracks_with_compilations['tempo'] = tempo
tracks_with_compilations['time_signature'] = time_signature
tracks_with_compilations['valence'] = valence

# %% [markdown]
# #### Collecting data from singles

# %%
results = spotify.artist_albums(nirvana_uri, album_type='single') # inspite of album_type='single' all items in this response are EPs

EPs = results['items']

tracks_from_EPs = {}

EP_names = []
track_names = []
duration = []
release_date = []
artists = []

acousticness = []
danceability = []
energy = []
instrumentalness = []
key = []
liveness = []
loudness = []
mode = []
speechiness = []
tempo = []
time_signature = []
valence = []

for EP in EPs:
    tracks = spotify.album_tracks(EP['id'])['items']
    audio = spotify.audio_features(tracks=[track['id'] for track in tracks])
    i=0
    for track in tracks:
        track_names.append(track['name'])
        EP_names.append(EP['name'])
        duration.append(math.floor(track['duration_ms']/1000))
        release_date.append(album['release_date'])
        artists.append(''.join([artist['name'] for artist in track['artists']]))
        acousticness.append(audio[i]['acousticness'])
        danceability.append(audio[i]['danceability'])
        energy.append(audio[i]['energy'])
        instrumentalness.append(audio[i]['instrumentalness'])
        key.append(audio[i]['key'])
        liveness.append(audio[i]['liveness'])
        loudness.append(audio[i]['loudness'])
        mode.append(audio[i]['mode'])
        speechiness.append(audio[i]['speechiness'])
        tempo.append(audio[i]['tempo'])
        time_signature.append(audio[i]['time_signature'])
        valence.append(audio[i]['valence'])
        i+=1
    
        
tracks_from_EPs['track_name'] = track_names

tracks_from_EPs['EP_name'] = EP_names

tracks_from_EPs['duration'] = duration

tracks_from_EPs['release_date'] = release_date

tracks_from_EPs['artists'] = artists

tracks_from_EPs['acousticness'] = acousticness
tracks_from_EPs['danceability'] = danceability
tracks_from_EPs['energy'] = energy
tracks_from_EPs['instrumentalness'] = instrumentalness
tracks_from_EPs['key'] = key
tracks_from_EPs['liveness'] = liveness
tracks_from_EPs['loudness'] = loudness
tracks_from_EPs['mode'] = mode
tracks_from_EPs['speechiness'] = speechiness
tracks_from_EPs['tempo'] = tempo
tracks_from_EPs['time_signature'] = time_signature
tracks_from_EPs['valence'] = valence
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1129 if buffer is not None:
# -> 1130     return self._sslobj.read(len, buffer)
#    1131 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\packages\six.py:770, in reraise(tp, value, tb)
#     769         raise value.with_traceback(tb)
# --> 770     raise value
#     771 finally:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:451, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     452     raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:340, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     339 if isinstance(err, SocketTimeout):
# --> 340     raise ReadTimeoutError(
#     341         self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     342     )
#     344 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     345 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 results = spotify.artist_albums(nirvana_uri, album_type='single') # inspite of album_type='single' all items in this response are EPs
#       3 EPs = results['items']
#       5 tracks_from_EPs = {}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\spotipy\client.py:418, in Spotify.artist_albums(self, artist_id, album_type, country, limit, offset)
#     407 """ Get Spotify catalog information about an artist's albums
#     408
#     409     Parameters:
#    (...)
#     414         - offset - the index of the first album to return
#     415 """
#     417 trid = self._get_id("artist", artist_id)
# --> 418 return self._get(
#     419     "artists/" + trid + "/albums",
#     420     album_type=album_type,
#     421     country=country,
#     422     limit=limit,
#     423     offset=offset,
#     424 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\spotipy\client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\spotipy\client.py:266, in Spotify._internal_call(self, method, url, payload, params)
#     262 logger.debug('Sending %s to %s with Params: %s Headers: %s and Body: %r ',
#     263              method, url, args.get("params"), headers, args.get('data'))
#     265 try:
# --> 266     response = self._session.request(
#     267         method, url, headers=headers, proxies=self.proxies,
#     268         timeout=self.requests_timeout, **args
#     269     )
#     271     response.raise_for_status()
#     272     results = response.json()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\adapters.py:578, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     576     raise SSLError(e, request=request)
#     577 elif isinstance(e, ReadTimeoutError):
# --> 578     raise ReadTimeout(e, request=request)
#     579 elif isinstance(e, _InvalidHeader):
#     580     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)

# %%
df = pd.DataFrame(tracks_with_albums)
df2 = pd.DataFrame(tracks_with_compilations)
df3 = pd.DataFrame(tracks_from_EPs)

nirvana = pd.concat([df, df2]).reset_index().drop('index', axis=1)

nirvana = pd.concat([nirvana, df3]).reset_index().drop('index', axis=1)

nirvana = nirvana[['track_name',
                   'duration',
                   'release_date',
                   'album_name',
                   'compilation_name',
                   'EP_name', 
                   'artists', 
                   'acousticness', 
                   'danceability', 
                   'energy', 
                   'instrumentalness',
                   'key', 
                   'liveness',
                   'loudness',
                   'mode',
                   'speechiness',
                   'tempo',
                   'time_signature',
                   'valence']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 9
#       5 nirvana = pd.concat([df, df2]).reset_index().drop('index', axis=1)
#       7 nirvana = pd.concat([nirvana, df3]).reset_index().drop('index', axis=1)
# ----> 9 nirvana = nirvana[['track_name',
#      10                    'duration',
#      11                    'release_date',
#      12                    'album_name',
#      13                    'compilation_name',
#      14                    'EP_name',
#      15                    'artists',
#      16                    'acousticness',
#      17                    'danceability',
#      18                    'energy',
#      19                    'instrumentalness',
#      20                    'key',
#      21                    'liveness',
#      22                    'loudness',
#      23                    'mode',
#      24                    'speechiness',
#      25                    'tempo',
#      26                    'time_signature',
#      27                    'valence']]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence'] not in index"

# %%
nirvana
# Out:
#                                             track_name  duration release_date  \
# 0            Smells Like Teen Spirit - Remastered 2021       300   2021-11-12
# 1                           In Bloom - Remastered 2021       254   2021-11-12
# 2                    Come As You Are - Remastered 2021       218   2021-11-12
# 3                              Breed - Remastered 2021       183   2021-11-12
# 4                            Lithium - Remastered 2021       256   2021-11-12
# 5                              Polly - Remastered 2021       174   2021-11-12
# 465            In Bloom / On A Plain / Lithium / Breed  Nirvana      0.000053
# 466            In Bloom / On A Plain / Lithium / Breed  Nirvana      0.001300
# 467            In Bloom / On A Plain / Lithium / Breed  Nirvana      0.008970
# 468            In Bloom / On A Plain / Lithium / Breed  Nirvana      0.000225
# 469                On A Plain / Lithium / Breed (Live)  Nirvana      0.001300
# 470                On A Plain / Lithium / Breed (Live)  Nirvana      0.008970
# 471                On A Plain / Lithium / Breed (Live)  Nirvana      0.000225
# 472                             Lithium / Breed (Live)  Nirvana      0.008970
# 473                             Lithium / Breed (Live)  Nirvana      0.000225
# 474        Breed (Live In Amsterdam, Netherlands/1991)  Nirvana      0.000225
#
#      danceability
# 0          0.4890
# 1          0.4430
# 2          0.5090
# 3          0.2950
# 4          0.6790
# 5          0.8170
# 6          0.3110
# 7          0.3430
# 8          0.3380
# 9          0.3300
# 10         0.4710
# 11         0.4260
# 12         0.2870
# 13         0.3600
# 14         0.1920
# 15         0.1190
# 16         0.2950
# 17         0.2810
# 18         0.3540
# 19         0.5090
# 20         0.3670
# 21         0.3250
# 22         0.0887
# 23         0.3310
# 24         0.2320
# 25         0.1410
# 26         0.3150
# 27         0.2010
# 28         0.2040
# 29         0.1420
# 30         0.4390
# 31         0.2330
# 32         0.1750
# 33         0.3510
# 34         0.4140
# 35         0.3410
# 36         0.4900
# 37         0.3950
# 38         0.2010
# 39         0.4040
# 40         0.3610
# 41         0.1460
# 42         0.2110
# 43         0.3970
# 44         0.1290
# 45         0.3050
# 46         0.3750
# 47         0.3460
# 48         0.3070
# 49         0.1770
# 50         0.6100
# 51         0.6840
# 52         0.5010
# 53         0.4880
# 54         0.5180
# 55         0.6900
# 56         0.6200
# 57         0.7040
# 58         0.5490
# 59         0.4400
# 60         0.5440
# 61         0.6600
# 62         0.6220
# 63         0.4560
# 64         0.6220
# 65         0.6110
# 66         0.5230
# 67         0.5450
# 68         0.5500
# 69         0.1230
# 70         0.2720
# 71         0.1670
# 72         0.2690
# 73         0.2550
# 74         0.3630
# 75         0.2770
# 76         0.3510
# 77         0.3410
# 78         0.3710
# 79         0.2500
# 80         0.2400
# 81         0.1870
# 82         0.4120
# 83         0.3920
# 84         0.4410
# 85         0.2190
# 86         0.3680
# 87         0.2590
# 88         0.4560
# 89         0.1700
# 90         0.3990
# 91         0.3170
# 92         0.3670
# 93         0.5460
# 94         0.1360
# 95         0.3960
# 96         0.2350
# 97         0.3270
# 98         0.2470
# 99         0.2290
# 100        0.4350
# 101        0.3300
# 102        0.2810
# 103        0.2260
# 104        0.3310
# 105        0.1020
# 106        0.3420
# 107        0.2160
# 108        0.1750
# 109        0.3340
# 110        0.2600
# 111        0.3340
# 112        0.3640
# 113        0.3570
# 114        0.3520
# 115        0.5260
# 116        0.2840
# 117        0.4100
# 118        0.3660
# 119        0.2080
# 120        0.2930
# 121        0.3930
# 122        0.2300
# 123        0.5420
# 124        0.3020
# 125        0.2650
# 126        0.3100
# 127        0.2440
# 128        0.1410
# 129        0.3910
# 130        0.1370
# 131        0.4120
# 132        0.2120
# 133        0.3990
# 134        0.2430
# 135        0.3900
# 136        0.3430
# 137        0.2810
# 138        0.3560
# 139        0.4190
# 140        0.4120
# 141        0.1850
# 142        0.4550
# 143        0.2060
# 144        0.2670
# 145        0.2220
# 146        0.6060
# 147        0.6830
# 148        0.5100
# 149        0.4830
# 150        0.4970
# 151        0.6900
# 152        0.6180
# 153        0.7030
# 154        0.5470
# 155        0.4500
# 156        0.5380
# 157        0.5410
# 158        0.5690
# 159        0.5730
# 160        0.4350
# 161        0.3100
# 162        0.2560
# 163        0.4200
# 164        0.4820
# 165        0.6970
# 166        0.2620
# 167        0.4680
# 168        0.4280
# 169        0.3200
# 170        0.2770
# 171        0.4460
# 172        0.4710
# 173        0.3670
# 174        0.3440
# 175        0.3700
# 176        0.4560
# 177        0.3880
# 178        0.5350
# 179        0.4180
# 180        0.4210
# 181        0.2800
# 182        0.2840
# 183        0.3780
# 184        0.4190
# 185        0.7000
# 186        0.2010
# 187        0.4190
# 188        0.4060
# 189        0.2700
# 190        0.2340
# 191        0.4180
# 192        0.3490
# 193        0.5150
# 194        0.7690
# 195        0.3190
# 196        0.3430
# 197        0.3170
# 198        0.1940
# 199        0.3640
# 200        0.6060
# 201        0.4240
# 202        0.3430
# 203        0.1240
# 204        0.2680
# 205        0.1650
# 206        0.2800
# 207        0.2470
# 208        0.3760
# 209        0.2800
# 210        0.4350
# 211        0.3100
# 212        0.2560
# 213        0.4200
# 214        0.4820
# 215        0.6970
# 216        0.2620
# 217        0.4680
# 218        0.4280
# 219        0.3200
# 220        0.2770
# 221        0.4460
# 222        0.4350
# 223        0.3100
# 224        0.2560
# 225        0.4200
# 226        0.4820
# 227        0.6970
# 228        0.2620
# 229        0.4680
# 230        0.4280
# 231        0.3200
# 232        0.2770
# 233        0.4460
# 234        0.4710
# 235        0.3670
# 236        0.3440
# 237        0.3700
# 238        0.4560
# 239        0.3880
# 240        0.5350
# 241        0.4180
# 242        0.4210
# 243        0.2800
# 244        0.2840
# 245        0.3780
# 246        0.4190
# 247        0.7000
# 248        0.2010
# 249        0.4190
# 250        0.4060
# 251        0.2700
# 252        0.2340
# 253        0.4180
# 254        0.3490
# 255        0.5150
# 256        0.7690
# 257        0.3190
# 258        0.3430
# 259        0.3170
# 260        0.1940
# 261        0.3640
# 262        0.6060
# 263        0.4240
# 264        0.3430
# 265        0.4250
# 266        0.4280
# 267        0.5460
# 268        0.3870
# 269        0.3160
# 270        0.3110
# 271        0.3300
# 272        0.3330
# 273        0.4000
# 274        0.3030
# 275        0.2830
# 276        0.4730
# 277        0.2890
# 278        0.4790
# 279        0.2980
# 280        0.5020
# 281        0.4360
# 282        0.5000
# 283        0.2620
# 284        0.6780
# 285        0.8300
# 286        0.2850
# 287        0.3250
# 288        0.3410
# 289        0.3670
# 290        0.4280
# 291        0.4270
# 292        0.2710
# 293        0.4430
# 294        0.3170
# 295        0.2390
# 296        0.2590
# 297        0.2800
# 298        0.1730
# 299        0.4290
# 300        0.4590
# 301        0.5170
# 302        0.4190
# 303        0.2640
# 304        0.4500
# 305        0.8090
# 306        0.3970
# 307        0.3510
# 308        0.3830
# 309        0.5900
# 310        0.5240
# 311        0.5290
# 312        0.3100
# 313        0.4000
# 314        0.3530
# 315        0.5900
# 316        0.2410
# 317        0.4630
# 318        0.3870
# 319        0.2830
# 320        0.4650
# 321        0.4460
# 322        0.4770
# 323        0.2860
# 324        0.6980
# 325        0.2610
# 326        0.3510
# 327        0.3980
# 328        0.4020
# 329        0.4720
# 330        0.5020
# 331        0.4360
# 332        0.5000
# 333        0.2620
# 334        0.6780
# 335        0.8300
# 336        0.2850
# 337        0.3250
# 338        0.3410
# 339        0.3670
# 340        0.4280
# 341        0.4270
# 342        0.2710
# 343        0.5020
# 344        0.4360
# 345        0.5000
# 346        0.2620
# 347        0.6780
# 348        0.8300
# 349        0.2850
# 350        0.3250
# 351        0.3410
# 352        0.3670
# 353        0.4280
# 354        0.4270
# 355        0.2710
# 356        0.4430
# 357        0.3170
# 358        0.2390
# 359        0.2590
# 360        0.2800
# 361        0.1730
# 362        0.4290
# 363        0.4590
# 364        0.5170
# 365        0.4190
# 366        0.2640
# 367        0.4500
# 368        0.8090
# 369        0.3970
# 370        0.3510
# 371        0.3830
# 372        0.5900
# 373        0.5240
# 374        0.5290
# 375        0.3100
# 376        0.4000
# 377        0.3530
# 378        0.5900
# 379        0.2410
# 380        0.4630
# 381        0.3870
# 382        0.2830
# 383        0.4110
# 384        0.4430
# 385        0.4130
# 386        0.2100
# 387        0.4790
# 388        0.5530
# 389        0.3700
# 390        0.4420
# 391        0.3870
# 392        0.1940
# 393        0.4200
# 394        0.2700
# 395        0.3450
# 396        0.2690
# 397        0.2570
# 398        0.3330
# 399        0.4110
# 400        0.4070
# 401        0.3050
# 402        0.2840
# 403        0.4090
# 404        0.3720
# 405        0.3600
# 406        0.2800
# 407        0.2400
# 408        0.4110
# 409        0.4430
# 410        0.4130
# 411        0.2100
# 412        0.4790
# 413        0.5530
# 414        0.3700
# 415        0.4420
# 416        0.3870
# 417        0.1940
# 418        0.4200
# 419        0.2700
# 420        0.3450
# 421           NaN
# 422           NaN
# 423           NaN
# 424           NaN
# 425           NaN
# 426           NaN
# 427           NaN
# 428           NaN
# 429           NaN
# 430           NaN
# 431           NaN
# 432           NaN
# 433           NaN
# 434           NaN
# 435           NaN
# 436           NaN
# 437           NaN
# 438           NaN
# 439           NaN
# 440           NaN
# 441           NaN
# 442           NaN
# 443           NaN
# 444           NaN
# 445           NaN
# 446           NaN
# 447           NaN
# 448           NaN
# 449           NaN
# 450           NaN
# 451           NaN
# 452           NaN
# 453           NaN
# 454           NaN
# 455           NaN
# 456           NaN
# 457           NaN
# 458           NaN
# 459           NaN
# 460           NaN
# 461           NaN
# 462           NaN
# 463           NaN
# 464           NaN
# 465           NaN
# 466           NaN
# 467           NaN
# 468           NaN
# 469           NaN
# 470           NaN
# 471           NaN
# 472           NaN
# 473           NaN
# 474           NaN

# %%
nirvana.to_csv('nirvana.csv')
